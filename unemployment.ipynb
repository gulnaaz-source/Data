# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
features = pd.read_csv(r'features.csv')

# %%
stores = pd.read_csv(r'stores.csv')

# %%
test = pd.read_csv(r'test.csv')

# %%
train = pd.read_csv(r'train.csv')

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
test
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %% [markdown]
# # FEATURES

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features.tail()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
features.mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4796\3400880853.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   features.mean()
# Store             23.000000
# Temperature       59.356198
# Fuel_Price         3.405992
# MarkDown1       7032.371786
# MarkDown2       3384.176594
# MarkDown3       1760.100180
# MarkDown4       3292.935886
# MarkDown5       4132.216422
# CPI              172.460809
# Unemployment       7.826821
# IsHoliday          0.071429
# dtype: float64

# %%
features1= features.dropna()
features1
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 92        1  2011-11-11        59.11       3.297   10382.90    6115.67
# 93        1  2011-11-18        62.25       3.308    6074.12     254.39
# 94        1  2011-11-25        60.14       3.236     410.31      98.00
# 95        1  2011-12-02        48.91       3.172    5629.51      68.00
# 96        1  2011-12-09        43.93       3.158    4640.65      19.00
# ...     ...         ...          ...         ...        ...        ...
# 8168     45  2013-03-01        39.72       3.890    6614.32     147.82
# 8169     45  2013-03-08        36.13       3.860   16382.54      88.67
# 8173     45  2013-04-05        43.94       3.763   16427.83    5341.41
# 8174     45  2013-04-12        57.39       3.724    8760.15    1713.11
# 8175     45  2013-04-19        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
features1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2069 entries, 92 to 8175
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         2069 non-null   int64
#  1   Date          2069 non-null   object
#  2   Temperature   2069 non-null   float64
#  3   Fuel_Price    2069 non-null   float64
#  4   MarkDown1     2069 non-null   float64
#  5   MarkDown2     2069 non-null   float64
#  6   MarkDown3     2069 non-null   float64
#  7   MarkDown4     2069 non-null   float64
#  8   MarkDown5     2069 non-null   float64
#  9   CPI           2069 non-null   float64
#  10  Unemployment  2069 non-null   float64
#  11  IsHoliday     2069 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 196.0+ KB

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
# %matplotlib inline
features["Unemployment"].plot()
# Out:
# <AxesSubplot: >

# %%
# %matplotlib inline
features1["Unemployment"].plot()
# Out:
# <AxesSubplot: >

# %%
features1.max()
# Out:
# Store                   45
# Date            2013-04-26
# Temperature          95.91
# Fuel_Price           4.301
# MarkDown1        103184.98
# MarkDown2        104519.54
# MarkDown3        149483.31
# MarkDown4         67474.85
# MarkDown5         771448.1
# CPI             228.976456
# Unemployment         12.89
# IsHoliday             True
# dtype: object

# %%
features1["Unemployment"].max()
# Out:
# 12.89

# %%
features1["Unemployment"].min()
# Out:
# 3.684

# %%
features1["Unemployment"].mean()
# Out:
# 7.252611406476559

# %%
features1.head(1)
# Out:
#     Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 92      1  2011-11-11        59.11       3.297    10382.9    6115.67
#
#     MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 92     215.07    2406.62    6551.42  217.998085         7.866      False

# %%
features1.tail(1)
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8175     45  2013-04-19        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 8175      44.38      60.83    1445.05  193.589304         8.335      False

# %%
 un_emp=features1.groupby(["Store"])["Unemployment"].mean()
un_emp
# Out:
# Store
# 1      7.029559
# 2      6.693344
# 3      6.486250
# 4      4.315483
# 5      5.737050
# 6      5.829000
# 7      7.830058
# 8      5.555636
# 9      5.357763
# 10     7.271922
# 11     6.487712
# 12    11.236717
# 13     5.840607
# 14     8.565683
# 15     8.017208
# 16     5.935814
# 17     5.937064
# 18     8.230183
# 19     8.021017
# 20     7.194538
# 21     6.707500
# 22     7.551923
# 23     4.145455
# 24     8.748656
# 25     7.189926
# 26     7.343455
# 27     8.037906
# 28    11.250138
# 29     9.136765
# 30     6.570571
# 31     6.702207
# 32     7.829937
# 33     7.806500
# 34     9.396073
# 35     8.700565
# 36     7.244000
# 37     6.863500
# 38    11.222000
# 39     6.785086
# 40     4.148706
# 41     6.333984
# 42     7.275833
# 43     9.121833
# 44     5.495500
# 45     8.562088
# Name: Unemployment, dtype: float64

# %%
features.groupby(["Store"])["IsHoliday"].count()
# Out:
# Store
# 1     182
# 2     182
# 3     182
# 4     182
# 5     182
# 6     182
# 7     182
# 8     182
# 9     182
# 10    182
# 11    182
# 12    182
# 13    182
# 14    182
# 15    182
# 16    182
# 17    182
# 18    182
# 19    182
# 20    182
# 21    182
# 22    182
# 23    182
# 24    182
# 25    182
# 26    182
# 27    182
# 28    182
# 29    182
# 30    182
# 31    182
# 32    182
# 33    182
# 34    182
# 35    182
# 36    182
# 37    182
# 38    182
# 39    182
# 40    182
# 41    182
# 42    182
# 43    182
# 44    182
# 45    182
# Name: IsHoliday, dtype: int64

# %%
mon_1=features.head(182)
mon_1
# Out:
#      Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0        1  2010-02-05        42.31       2.572        NaN        NaN
# 1        1  2010-02-12        38.51       2.548        NaN        NaN
# 2        1  2010-02-19        39.93       2.514        NaN        NaN
# 3        1  2010-02-26        46.63       2.561        NaN        NaN
# 4        1  2010-03-05        46.50       2.625        NaN        NaN
# ..     ...         ...          ...         ...        ...        ...
# 177      1  2013-06-28        83.94       3.495    4205.98     796.70
# 178      1  2013-07-05        79.85       3.422    7649.99    3503.29
# 179      1  2013-07-12        83.12       3.400    6089.94    1362.42
# 180      1  2013-07-19        79.26       3.556    3117.04    1060.39
# 181      1  2013-07-26        81.54       3.620     332.17     673.19
#
#      MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
x=test.groupby(["Store","IsHoliday","Dept"],as_index=False)["IsHoliday"].count()
x
# Out:
#       Store  Dept  IsHoliday
# 0         1     1         36
# 1         1     2         36
# 2         1     3         36
# 3         1     4         36
# 4         1     5         36
# ...     ...   ...        ...
# 6213     45    93          3
# 6214     45    94          3
# 6215     45    95          3
# 6216     45    97          3
# 6217     45    98          3
#
# [6218 rows x 3 columns]
